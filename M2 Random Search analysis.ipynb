# %%
import pickle as pkl
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV

# %%
with open('initial_models/results.pkl', 'rb') as open_file:
    df = pkl.load(open_file)

# %%
df
# Out:
#         auc                                          estimator model_label  \
# 0  0.694991  RandomizedSearchCV(cv=None, error_score='raise...    lr_model
# 1  0.683402  RandomizedSearchCV(cv=None, error_score='raise...    gb_model
# 2  0.681272  RandomizedSearchCV(cv=None, error_score='raise...    rf_model
# 3  0.629043  RandomizedSearchCV(cv=None, error_score='raise...   knn_model
#
#    precision   recall
# 0   0.828011  0.99294
# 1   0.821441  1.00000
# 2   0.821441  1.00000
# 3   0.822152  0.99893

# %%
df['estimator'][3]
# Out:
# RandomizedSearchCV(cv=None, error_score='raise',
#           estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#            weights='uniform'),
#           fit_params=None, iid=True, n_iter=3, n_jobs=1,
#           param_distributions={'n_neighbors': [5, 10, 25, 50, 125, 200]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring=None, verbose=0)

# %%
with open('results.pkl', 'rb') as open_file:
    df = pkl.load(open_file)

# %%
df
# Out:
#         auc                                          estimator model_label  \
# 0  0.941865  RandomizedSearchCV(cv=5, error_score='raise',\...    gb_model
#
#    precision    recall
# 0   0.825725  0.976854

# %%
estimators = df['estimator']

# %%
df2 = pd.DataFrame(estimators[0].cv_results_)
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ...

# %%
df2
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       10.204175      0.444098         0.170871        0.182943
# 1        6.668079      0.066712         0.046460        0.000181
# 2        8.890515      0.502032         0.054775        0.001491
# 3       14.144192      0.394073         0.091074        0.003574
# 4       12.641515      0.387982         0.084917        0.012208
# 5       18.274816      2.925300         0.100519        0.016605
# 6       20.613376      3.220489         0.128196        0.020269
# 7       14.580327      0.587225         0.086509        0.008000
# 8       19.447369      0.998916         0.122633        0.018352
# 9        7.678491      0.531124         0.071521        0.026667
# 10       8.463075      1.042000         0.052333        0.006373
# 11       7.345035      0.655813         0.048060        0.003028
# 12       4.789986      0.233808         0.033575        0.000830
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 22 columns):
# mean_fit_time              20 non-null float64
# std_fit_time               20 non-null float64
# mean_score_time            20 non-null float64
# std_score_time             20 non-null float64
# param_subsample            20 non-null object
# param_n_estimators         20 non-null object
# param_min_samples_split    20 non-null object
# param_max_features         20 non-null object
# param_max_depth            20 non-null object
# param_learning_rate        20 non-null object
# params                     20 non-null object
# split0_test_score          20 non-null float64
# split1_test_score          20 non-null float64
# split2_test_score          20 non-null float64
# mean_test_score            20 non-null float64
# std_test_score             20 non-null float64
# rank_test_score            20 non-null int32
# split0_train_score         20 non-null float64
# ...

# %%
df2
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        2.498196      0.040346         0.034440        0.004623
# 1        3.985624      0.151324         0.066289        0.009867
# 2        1.249412      0.077011         0.019441        0.005455
# 3       12.288471      0.323184         0.132621        0.028036
# 4        3.827744      0.188412         0.057588        0.006567
# 5        0.789635      0.038108         0.012567        0.002928
# 6        0.794080      0.053042         0.009744        0.000368
# 7        1.270019      0.039775         0.015744        0.000229
# 8        0.876324      0.053269         0.015031        0.006188
# 9        3.023418      0.170942         0.049527        0.007215
# 10       0.343870      0.032156         0.006114        0.000073
# 11       1.350738      0.041934         0.019523        0.002600
# 12       1.294740      0.009313         0.020293        0.000038
# ...

# %%
with open('results.pkl', 'rb') as open_file:
    df = pkl.load(open_file)

# %%
estimators = df['estimator']

# %%
df2 = pd.DataFrame(estimators[1].cv_results_)
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ...

# %%
df2['rank_test_score'].sort_values(by='rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 43       2.378899      0.092708         0.034081        0.002181
# 19       2.172219      0.032643         0.034289        0.003061
# 20       6.138677      0.112831         0.073024        0.002885
# 17       1.643798      0.033390         0.034090        0.007726
# 1        1.983177      0.036600         0.031367        0.002614
# 74       1.931411      0.159581         0.036851        0.007591
# 27       1.670381      0.020969         0.030338        0.000382
# 50       2.452297      0.018156         0.039900        0.000473
# 49       1.161518      0.091694         0.020124        0.001087
# 8        1.208213      0.054231         0.019780        0.001823
# 97       3.343714      0.009261         0.053021        0.000569
# 3        1.692079      0.046484         0.031970        0.003006
# 56       3.887698      0.083204         0.057546        0.010055
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df2['rank_test_score'], df2['param_min_weight_fraction_leaf'])

# %%
with open('thurs_best_estimator.pkl', 'wb') as open_file:
    pkl.dump(estimators[1].best_estimator_, open_file)

# %%
with open('thurs_best_estimator.pkl', 'rb') as open_file:
    estimator = pkl.load(open_file)

# %%
estimator.feature_importances_
# Out:
# array([0.23190819, 0.085292  , 0.00583019, 0.01080364, 0.02275574,
#        0.00165642, 0.        , 0.00480404, 0.00303667, 0.00318256,
#        0.00750465, 0.01398221, 0.        , 0.00186185, 0.        ,
#        0.00280254, 0.0030372 , 0.00174132, 0.00301771, 0.00265845,
#        0.00408772, 0.002335  , 0.00563193, 0.00450273, 0.00519195,
#        0.        , 0.        , 0.00183487, 0.00594562, 0.00174426,
#        0.00052576, 0.00092953, 0.0072701 , 0.00133699, 0.00053608,
#        0.00110306, 0.00127417, 0.00058384, 0.00188511, 0.00220202,
#        0.00334539, 0.00113379, 0.00332598, 0.00152365, 0.00256156,
#        0.00238561, 0.00235124, 0.        , 0.00185567, 0.00226948,
#        0.00486753, 0.00070069, 0.00494002, 0.00582076, 0.00364096,
#        0.00306295, 0.00323946, 0.00677896, 0.00478507, 0.0057842 ,
#        0.00855766, 0.00077905, 0.00263884, 0.00070087, 0.00203861,
#        0.0039118 , 0.        , 0.        , 0.00366782, 0.00207644,
# ...

# %%
with open('M2_data.csv', 'r') as open_file:
    df = pd.read_csv(open_file, index_col=0)

# %%
df.columns
# Out:
# Index(['auc', 'estimator', 'model_label', 'precision', 'recall'], dtype='object')

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mb = MultiLabelBinarizer()

# %%
a= mb.fit_transform(df['subject_category'])

# %%
type(df['subject_category'][5])
# Out:
# str

# %%
df, mapper = main.transform(df)

# %%
a = mapper.fit_transform(df)
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
dict(zip(mapper.transformed_names_, estimator.feature_importances_))
# Out:
# {'project_cost': 0.2319081862000381,
#  'perc_lunch': 0.0852920011046295,
#  'grade_level_Grades 3-5': 0.005830186926307866,
#  'grade_level_Grades 6-8': 0.010803640242472939,
#  'grade_level_Grades 9-12': 0.02275573805243874,
#  'grade_level_Grades PreK-2': 0.0016564164062012688,
#  'grade_level_unknown': 0.0,
#  'metro_rural': 0.004804038164129298,
#  'metro_suburban': 0.0030366720051828253,
#  'metro_town': 0.0031825586221203832,
#  'metro_unknown': 0.007504649318517623,
#  'metro_urban': 0.013982208561251198,
#  'subject_category_ ': 0.0,
#  'subject_category_&': 0.001861852531296182,
#  "subject_category_'": 0.0,
#  'subject_category_,': 0.0028025415893072002,
#  'subject_category_A': 0.003037197224886196,
#  'subject_category_C': 0.0017413183619799308,
#  'subject_category_H': 0.0030177100155027938,
#  'subject_category_L': 0.0026584532934179235,
#  'subject_category_M': 0.0040877228360114365,
#  'subject_category_N': 0.0023349957500284233,
# ...

# %%
import pickle as pkl

# %%
df2 = pkl.load(open('observations.pkl', 'rb'))

# %%
df2['subject_category'][1]
# Out:
# "['Literacy & Language']"

# %%
importances = {'project_cost': 0.2319081862000381,
 'perc_lunch': 0.0852920011046295,
 'grade_level_Grades 3-5': 0.005830186926307866,
 'grade_level_Grades 6-8': 0.010803640242472939,
 'grade_level_Grades 9-12': 0.02275573805243874,
 'grade_level_Grades PreK-2': 0.0016564164062012688,
 'grade_level_unknown': 0.0,
 'metro_rural': 0.004804038164129298,
 'metro_suburban': 0.0030366720051828253,
 'metro_town': 0.0031825586221203832,
 'metro_unknown': 0.007504649318517623,
 'metro_urban': 0.013982208561251198,
 'subject_category_ ': 0.0,
 'subject_category_&': 0.001861852531296182,
 "subject_category_'": 0.0,
 'subject_category_,': 0.0028025415893072002,
 'subject_category_A': 0.003037197224886196,
 'subject_category_C': 0.0017413183619799308,
 'subject_category_H': 0.0030177100155027938,
 'subject_category_L': 0.0026584532934179235,
 'subject_category_M': 0.0040877228360114365,
 'subject_category_N': 0.0023349957500284233,
 'subject_category_S': 0.0056319309598833085,
 'subject_category_T': 0.004502726794103363,
 'subject_category_W': 0.005191952402508284,
 'subject_category_[': 0.0,
 'subject_category_]': 0.0,
 'subject_category_a': 0.0018348710872801788,
 'subject_category_c': 0.005945624520993603,
 'subject_category_d': 0.0017442617465519767,
 'subject_category_e': 0.0005257565444929419,
 'subject_category_g': 0.000929530440686337,
 'subject_category_h': 0.00727009950119541,
 'subject_category_i': 0.0013369924329408903,
 'subject_category_l': 0.0005360805257058439,
 'subject_category_m': 0.0011030550068529678,
 'subject_category_n': 0.0012741653824628865,
 'subject_category_o': 0.0005838390989752524,
 'subject_category_p': 0.0018851087454570543,
 'subject_category_r': 0.0022020246771968584,
 'subject_category_s': 0.0033453867848432252,
 'subject_category_t': 0.0011337861423368584,
 'subject_category_u': 0.0033259760081343587,
 'subject_category_v': 0.0015236493343601366,
 'subject_category_y': 0.0025615581792431106,
 'subject_subcategory_ ': 0.002385610196481315,
 'subject_subcategory_&': 0.002351244459976433,
 "subject_subcategory_'": 0.0,
 'subject_subcategory_,': 0.0018556745857493634,
 'subject_subcategory_A': 0.0022694757192790265,
 'subject_subcategory_C': 0.0048675265064833835,
 'subject_subcategory_D': 0.0007006885730639137,
 'subject_subcategory_E': 0.004940020799217186,
 'subject_subcategory_F': 0.005820756828763496,
 'subject_subcategory_G': 0.0036409573302180185,
 'subject_subcategory_H': 0.0030629496750321076,
 'subject_subcategory_I': 0.003239461557422544,
 'subject_subcategory_L': 0.0067789588525499,
 'subject_subcategory_M': 0.004785066043220152,
 'subject_subcategory_N': 0.005784204173949006,
 'subject_subcategory_O': 0.008557656175403213,
 'subject_subcategory_P': 0.0007790523352688903,
 'subject_subcategory_S': 0.002638835675527543,
 'subject_subcategory_T': 0.0007008697285916366,
 'subject_subcategory_V': 0.0020386108568632845,
 'subject_subcategory_W': 0.0039117970951215025,
 'subject_subcategory_[': 0.0,
 'subject_subcategory_]': 0.0,
 'subject_subcategory_a': 0.0036678169556375773,
 'subject_subcategory_c': 0.0020764363514975803,
 'subject_subcategory_d': 0.0003439700050317108,
 'subject_subcategory_e': 0.001751678901200769,
 'subject_subcategory_f': 0.0035585119771531643,
 'subject_subcategory_g': 0.004955240612774209,
 'subject_subcategory_h': 0.001044519783336222,
 'subject_subcategory_i': 0.0035754117315400023,
 'subject_subcategory_l': 0.002682444728627885,
 'subject_subcategory_m': 0.005680870432089682,
 'subject_subcategory_n': 0.0006870827195395464,
 'subject_subcategory_o': 0.003363514334673107,
 'subject_subcategory_p': 0.002414656382282687,
 'subject_subcategory_r': 0.0042663903001098355,
 'subject_subcategory_s': 0.0025644688413521246,
 'subject_subcategory_t': 0.004077332331210483,
 'subject_subcategory_u': 0.0013710818566808828,
 'subject_subcategory_v': 0.004301487997374932,
 'subject_subcategory_x': 0.00293053029987223,
 'subject_subcategory_y': 0.002055730891007752,
 'resource_category_Art Supplies': 0.005776493561555545,
 'resource_category_Books': 0.018284432902516808,
 'resource_category_Classroom Basics': 0.00659912378245174,
 'resource_category_Computers & Tablets': 0.011790970761063302,
 'resource_category_Educational Kits & Games': 0.010150601713640437,
 'resource_category_Flexible Seating': 0.007544746140915316,
 'resource_category_Food, Clothing & Hygiene': 0.009661570922577255,
 'resource_category_Instructional Technology': 0.00692598503269192,
 'resource_category_Lab Equipment': 0.0009423655541962449,
 'resource_category_Musical Instruments': 0.005834978205014874,
 'resource_category_Other': 0.0013037002676040807,
 'resource_category_Reading Nooks, Desks & Storage': 0.011561439640651337,
 'resource_category_Sports & Exercise Equipment': 0.010812137883109302,
 'resource_category_Supplies': 0.01846176778244075,
 'resource_category_Technology': 0.03297795667455817,
 'resource_category_Trips': 0.0036756098223156798,
 'resource_category_Unknown': 0.0,
 'resource_category_Visitors': 0.0016883963683279035,
 'title_length': 0.02028197179630187,
 'title_nouns': 0.022744992238860742,
 'title_qualifiers': 0.010856207040180605,
 'title_verbs': 0.008857198071058921,
 'essay_length': 0.043293569191129554,
 'essay_nouns': 0.04773084061177886,
 'essay_qualifiers': 0.027113238540321296,
 'essay_verbs': 0.05996464737163853}

# %%
res = dict()
for key, item in importances.items():
    if key[:8] == 'resource':
        res[key] = item

# %%
import operator
sorted(res.items(), key = operator.itemgetter(1))
# Out:
# [('resource_category_Unknown', 0.0),
#  ('resource_category_Lab Equipment', 0.0009423655541962449),
#  ('resource_category_Other', 0.0013037002676040807),
#  ('resource_category_Visitors', 0.0016883963683279035),
#  ('resource_category_Trips', 0.0036756098223156798),
#  ('resource_category_Art Supplies', 0.005776493561555545),
#  ('resource_category_Musical Instruments', 0.005834978205014874),
#  ('resource_category_Classroom Basics', 0.00659912378245174),
#  ('resource_category_Instructional Technology', 0.00692598503269192),
#  ('resource_category_Flexible Seating', 0.007544746140915316),
#  ('resource_category_Food, Clothing & Hygiene', 0.009661570922577255),
#  ('resource_category_Educational Kits & Games', 0.010150601713640437),
#  ('resource_category_Sports & Exercise Equipment', 0.010812137883109302),
#  ('resource_category_Reading Nooks, Desks & Storage', 0.011561439640651337),
#  ('resource_category_Computers & Tablets', 0.011790970761063302),
# ...

# %%
b = estimator.estimators_[-1][0].tree_

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.tree import export_graphviz

# %%
export_graphviz(estimator.estimators_[-1][0], feature_names=list(importances.keys()))
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/tree/export.py:399: DeprecationWarning: out_file can be set to None starting from 0.18. This will be the default in 0.20.
#   DeprecationWarning)

# %%
df = pkl.load(open('results.pkl', 'rb'))

# %%
df
# Out:
#         auc                                          estimator model_label  \
# 0  0.738016  RandomizedSearchCV(cv=5, error_score='raise',\...    gb_model
#
#    precision   recall
# 0   0.827854  0.98644

# %%
c = df['estimator'][0]

# %%
importances = c.best_estimator_

# %%
importances
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=4,
#               max_features='sqrt', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=200,
#               min_weight_fraction_leaf=0.005, n_estimators=200,
#               presort='auto', random_state=10, subsample=0.8, verbose=0,
#               warm_start=False)

# %%
m2data = pkl.load(open('observations.pkl', 'rb'))

# %%
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import StandardScaler, Imputer, LabelBinarizer, MultiLabelBinarizer
mapper = DataFrameMapper([
        (['project_cost'], StandardScaler()),
        (['perc_lunch'], [Imputer(strategy='median'), StandardScaler()]),
        (['grade_level'], LabelBinarizer()),
        (['metro'], LabelBinarizer()),
        ('subject_category', MultiLabelBinarizer()),
        ('subject_subcategory', MultiLabelBinarizer()),
        (['resource_category'], LabelBinarizer()),
        (['title_length'], StandardScaler()),
        (['title_noun_density'], StandardScaler()),
        (['title_qualifier_density'], StandardScaler()),
        (['title_verb_density'], StandardScaler()),
        (['essay_length'], StandardScaler()),
        (['essay_noun_density'], StandardScaler()),
        (['essay_qualifier_density'], StandardScaler()),
        (['essay_verb_density'], StandardScaler()),
        (['num_items'], [Imputer(strategy='median'), StandardScaler()])
    ])

# %%
mapper.fit_transform(m2data)
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[-0.19079014, -0.59333381,  1.        , ...,  0.68417067,
#         -0.81146633,  1.50044554],
#        [-0.18478948, -1.669906  ,  0.        , ...,  1.17928596,
#         -2.102391  , -0.43007017],
#        [-0.40095909, -1.669906  ,  0.        , ..., -0.04652912,
#         -0.79593829, -0.50157075],
#        ...,
#        [-0.40313642,  1.0861188 ,  0.        , ..., -0.2536024 ,
#          1.15748301, -0.3228193 ],
#        [-0.19935358, -0.59333381,  1.        , ...,  0.10284087,
#         -0.32887531,  0.0704339 ],
#        [ 0.6472812 , -1.02396269,  1.        , ...,  0.7807868 ,
#         -1.12615824, -0.3228193 ]])

# %%
col_names = mapper.transformed_names_

# %%
graph = export_graphviz(last_tree, feature_names=col_names, out_file='monday_SMOTE_density_last_tree.dot', class_names=['funded', 'expired'], filled=True)

# %%
from sklearn.tree import graphviz
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-53-33a959216d70> in <module>()
# ----> 1 from sklearn.tree import graphviz
#
# ImportError: cannot import name 'graphviz'

# %%
first_tree = c.best_estimator_[0][0]

# %%
last_tree = c.best_estimator_[-1][0]

# %%
pkl.dump(c.best_estimator_, open('monday_SMOTE_best_estimator_density.pkl', 'wb'))

# %%
gboosts = df['estimator'][1]

# %%
c.best_estimator_.estimators_[-1, 0]
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=6,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=300,
#            min_weight_fraction_leaf=0.0001, presort='auto',
#            random_state=<mtrand.RandomState object at 0x7f76c590e4c8>,
#            splitter='best')

# %%
pd.DataFrame(gboosts.cv_results_).sort_values(by='rank_test_score')
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ...

# %%
df = pkl.load(open('results.pkl', 'rb'))

# %%
pd.DataFrame(df['estimator'][1].cv_results_)[['param_learning_rate', 'rank_test_score']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-7d5743565b0e> in <module>()
# ----> 1 pd.DataFrame(df['estimator'][1].cv_results_)[['param_learning_rate', 'rank_test_score']]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3101         try:
#    3102             return self._engine.get_value(s, k,
# -> 3103                                           tz=getattr(series.dtype, 'tz', None))
#    3104         except KeyError as e1:
# ...

# %%
df
# Out:
#         auc                                          estimator model_label  \
# 0  0.738016  RandomizedSearchCV(cv=5, error_score='raise',\...    gb_model
#
#    precision   recall
# 0   0.827854  0.98644

# %%
col_names
# Out:
# ['project_cost',
#  'perc_lunch',
#  'grade_level_Grades 3-5',
#  'grade_level_Grades 6-8',
#  'grade_level_Grades 9-12',
#  'grade_level_Grades PreK-2',
#  'grade_level_unknown',
#  'metro_rural',
#  'metro_suburban',
#  'metro_town',
#  'metro_unknown',
#  'metro_urban',
#  'subject_category_Applied Learning',
#  'subject_category_Care & Hunger',
#  'subject_category_Health & Sports',
#  'subject_category_History & Civics',
#  'subject_category_Literacy & Language',
#  'subject_category_Math & Science',
#  'subject_category_Music & The Arts',
#  'subject_category_Special Needs',
#  'subject_category_Warmth',
#  'subject_subcategory_Applied Sciences',
#  'subject_subcategory_Care & Hunger',
#  'subject_subcategory_Character Education',
#  'subject_subcategory_Civics & Government',
#  'subject_subcategory_College & Career Prep',
#  'subject_subcategory_Community Service',
#  'subject_subcategory_ESL',
#  'subject_subcategory_Early Development',
#  'subject_subcategory_Economics',
# ...

# %%
with open('ORobservations.pkl', 'rb') as open_file:
    ORdf = pkl.load(open_file)

# %%
mapper.fit_transform(ORdf)
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[-0.50770997, -0.93742321,  0.        , ..., -0.18064191,
#         -1.75711794,  0.72385459],
#        [ 0.59658718,  1.03195307,  0.        , ..., -0.66228352,
#         -0.35366488, -0.46355592],
#        [-0.24361511,  1.3525492 ,  1.        , ...,  0.48401393,
#          0.55783458, -0.09036976],
#        ...,
#        [-0.52132059, -0.47942872,  1.        , ..., -0.39355788,
#          0.43026757, -0.59925998],
#        [-0.31275415, -0.47942872,  1.        , ...,  0.50886767,
#         -1.43940979,  0.38459444],
#        [-0.42915028, -0.47942872,  1.        , ..., -0.04633613,
#         -0.26405176,  0.38459444]])

# %%
or_names = (mapper.transformed_names_)

# %%
for item in col_names:
    if item not in or_names:
        print(item)
# Out:
# resource_category_Unknown

# %%
with open('ORobservations.pkl', 'wb') as open_file:
    pkl.dump(ORdf, open_file)

# %%
for item in or_col_names:
    if item not in or_col_names:
        print(item)

# %%
with open('observations.pkl', 'rb') as open_file:
    m2df = pkl.load(open_file)

# %%
def parts_of_speech_density(df):
    df['title_noun_density'] = df.apply(lambda row: row['title_nouns']/row['title_length'], axis=1)
    df['title_qualifier_density'] = df.apply(lambda row: row['title_qualifiers']/row['title_length'], axis=1)
    df['title_verb_density'] = df.apply(lambda row: row['title_verbs']/row['title_length'], axis=1)
    
    df['essay_noun_density'] = df.apply(lambda row: row['essay_nouns']/row['essay_length'], axis=1)
    df['essay_qualifier_density'] = df.apply(lambda row: row['essay_qualifiers']/row['essay_length'], axis=1)
    df['essay_verb_density'] = df.apply(lambda row: row['essay_verbs']/row['essay_length'], axis=1)

    return df

# %%
m2df = parts_of_speech_density(m2df)

# %%
with open('observations.pkl', 'wb') as open_file:
    pkl.dump(m2df, open_file)

# %%
m2df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22757 entries, 0 to 25702
# Data columns (total 25 columns):
# project_cost               22757 non-null float64
# grade_level                22757 non-null object
# funded                     22757 non-null int64
# subject_category           22757 non-null object
# subject_subcategory        22757 non-null object
# resource_category          22757 non-null object
# project_title              22757 non-null object
# project_essay              22757 non-null object
# perc_lunch                 22718 non-null float64
# metro                      22757 non-null object
# num_items                  22309 non-null float64
# title_length               22757 non-null int64
# essay_length               22757 non-null int64
# title_nouns                22757 non-null int64
# title_qualifiers           22757 non-null int64
# title_verbs                22757 non-null int64
# essay_nouns                22757 non-null int64
# ...
